# %% [markdown]
# <a href="https://colab.research.google.com/github/codebjjung/DATA_ANALYSIS/blob/main/Kmeans_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
height = [187.0, 182.1, 177.3, 181.2, 175.1, 173.5, 171.6, 169.8, 165.1, 176.4, 172.3, 170.2]
weight = [82.1, 78.3, 65.2, 58.3, 72.1, 68.5, 41.2, 66.6, 61.7, 68.3, 77.7, 99.9]

# %%
import pandas as pd
import numpy as np

# %%
data = {'Height' : height, 'Weight' : weight}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Height  Weight
# 0    187.0    82.1
# 1    182.1    78.3
# 2    177.3    65.2
# 3    181.2    58.3
# 4    175.1    72.1
# 5    173.5    68.5
# 6    171.6    41.2
# 7    169.8    66.6
# 8    165.1    61.7
# 9    176.4    68.3
# 10   172.3    77.7
# 11   170.2    99.9
